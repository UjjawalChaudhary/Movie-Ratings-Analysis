# %%
# Import required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load movie dataset

df = pd.read_csv("movie_analysis_dataset.csv")

# Display first 5 rows
df.head()
# Out:
#      Movie     Genre    Director  Year  Rating  Budget  Revenue
# 0  Movie 1  Thriller  Director D  2011     7.7     121      465
# 1  Movie 2    Action  Director C  2013     7.1     245     1025
# 2  Movie 3    Action  Director E  2017     7.8     124      585
# 3  Movie 4    Sci-Fi  Director C  2021     7.4     210      433
# 4  Movie 5    Sci-Fi  Director E  2011     7.8      34      122

# %%
# Check dataset information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Movie     200 non-null    object
#  1   Genre     200 non-null    object
#  2   Director  200 non-null    object
#  3   Year      200 non-null    int64
#  4   Rating    200 non-null    float64
#  5   Budget    200 non-null    int64
#  6   Revenue   200 non-null    int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 11.1+ KB

# %%
# Generate statistical summary

df.describe()
# Out:
#               Year      Rating      Budget      Revenue
# count   200.000000  200.000000  200.000000   200.000000
# mean   2017.400000    7.025500  133.360000   413.310000
# std       4.272149    0.930607   69.994906   268.693515
# min    2010.000000    4.800000   21.000000    32.000000
# 25%    2014.000000    6.300000   63.750000   194.000000
# 50%    2017.500000    7.100000  132.500000   368.000000
# 75%    2021.000000    7.700000  200.000000   582.000000
# max    2024.000000    9.500000  249.000000  1214.000000

# %%
# Check missing values in each column

df.isnull().sum()
# Out:
# Movie       0
# Genre       0
# Director    0
# Year        0
# Rating      0
# Budget      0
# Revenue     0
# dtype: int64

# %%
# Remove rows with missing values (safe practice)

df = df.dropna()

# %%
# Rating statistics

print("Rating Mean:", np.mean(df["Rating"]))
print("Rating Median:", np.median(df["Rating"]))
print("Rating Standard Deviation:", np.std(df["Rating"]))
# Out:
# Rating Mean: 7.025499999999999
# Rating Median: 7.1
# Rating Standard Deviation: 0.9282778409506497

# %%
# Budget statistics

print("Budget Mean:", np.mean(df["Budget"]))
print("Budget Median:", np.median(df["Budget"]))
print("Budget Standard Deviation:", np.std(df["Budget"]))
# Out:
# Budget Mean: 133.36
# Budget Median: 132.5
# Budget Standard Deviation: 69.8196992259348

# %%
# Revenue statistics

print("Revenue Mean:", np.mean(df["Revenue"]))
print("Revenue Median:", np.median(df["Revenue"]))
print("Revenue Standard Deviation:", np.std(df["Revenue"]))
# Out:
# Revenue Mean: 413.31
# Revenue Median: 368.0
# Revenue Standard Deviation: 268.02093929392896

# %%
# Average rating by genre

genre_rating = df.groupby("Genre")["Rating"].mean()

genre_rating
# Out:
# Genre
# Action      7.111111
# Comedy      6.973333
# Drama       7.030000
# Romance     6.971429
# Sci-Fi      7.275000
# Thriller    6.797500
# Name: Rating, dtype: float64

# %%
# Average rating by director

director_rating = df.groupby("Director")["Rating"].mean()

director_rating
# Out:
# Director
# Director A    7.009677
# Director B    7.000000
# Director C    7.156250
# Director D    7.115789
# Director E    6.855102
# Name: Rating, dtype: float64

# %%
# Average rating by year

year_rating = df.groupby("Year")["Rating"].mean()

year_rating
# Out:
# Year
# 2010    7.066667
# 2011    7.240000
# 2012    6.750000
# 2013    7.142857
# 2014    6.638462
# 2015    6.512500
# 2016    6.905263
# 2017    7.285714
# 2018    7.329412
# 2019    7.200000
# 2020    7.100000
# 2021    7.020000
# 2022    7.153333
# 2023    6.770000
# 2024    6.957895
# Name: Rating, dtype: float64

# %%
# Bar Plot: Average Rating by Genre and Director

plt.figure(figsize=(12,5))

# Genre Ratings
plt.subplot(1, 2, 1)
plt.bar(genre_rating.index, genre_rating.values)
plt.title("Average Rating by Genre")
plt.xlabel("Genre")
plt.ylabel("Average Rating")

# Director Ratings
plt.subplot(1, 2, 2)
plt.bar(director_rating.index, director_rating.values)
plt.title("Average Rating by Director")
plt.xlabel("Director")
plt.ylabel("Average Rating")

plt.tight_layout()

plt.savefig("genre_director_rating_barplot.png")

plt.show()

# %%
# Line Plot: Average Ratings Over Years

plt.figure(figsize=(8,5))

plt.plot(
    year_rating.index,
    year_rating.values,
    marker="o"
)

plt.title("Average Movie Ratings Over Years")
plt.xlabel("Year")
plt.ylabel("Average Rating")

plt.grid(True)

plt.savefig("year_rating_trend.png")

plt.show()

# %%
# Scatter Plot: Budget vs Rating

plt.figure(figsize=(8,5))

plt.scatter(
    df["Budget"],
    df["Rating"]
)

plt.title("Budget vs Rating")
plt.xlabel("Budget")
plt.ylabel("Rating")

plt.savefig("budget_vs_rating.png")

plt.show()

# %%
# Scatter Plot: Revenue vs Rating

plt.figure(figsize=(8,5))

plt.scatter(
    df["Revenue"],
    df["Rating"]
)

plt.title("Revenue vs Rating")
plt.xlabel("Revenue")
plt.ylabel("Rating")

plt.savefig("revenue_vs_rating.png")

plt.show()

# %%
# Top 10 Rated Movies

top_movies = df.nlargest(10, "Rating")

plt.figure(figsize=(10,5))

plt.barh(
    top_movies["Movie"],
    top_movies["Rating"]
)

plt.title("Top Rated Movies")
plt.xlabel("Rating")
plt.ylabel("Movie")

plt.savefig("top_rated_movies.png")

plt.show()

# %% [markdown]
# # Conclusion
#
# This project analyzed movie data using Pandas, NumPy, and Matplotlib.
#
# Key Findings:
#
# - Movie ratings were analyzed using statistical measures such as mean, median, and standard deviation.
# - Genre-wise and director-wise grouping revealed differences in average ratings.
# - Rating trends over the years were examined using line plots.
# - Relationships between budget, revenue, and ratings were explored using scatter plots.
# - Top-rated movies were identified through ranking analysis.
#
# This project demonstrates data cleaning, statistical analysis, grouping operations, and data visualization techniques using Python.
